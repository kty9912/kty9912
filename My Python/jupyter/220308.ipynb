# %%
# class 하나 생성
# 1. 인자값으로 url(주소) -> csv 파일의 주소(상대경로)
# 2. 함수를 하나 생성 -> url에 있는 csv 파일을 읽어오고, 'Country' 기준으로 sort, 인덱스 값을 초기화
# 3. 함수를 하나 생성 -> 인자값을 리스트로 받는다. -> 이 매개변수를 기준으로 columns 삭제

# %%
import pandas as pd

class Change_dt():
    def __init__(self, input_url):
        self.url = input_url
    
    def csv_read(self): #(self, input_sort = "Country", input_inplace = True):
        self.dt = pd.read_csv(self.url)
        self.dt.sort_values("Country", inplace=True) #(input_sort, inplace=input_inplace)
        self.dt.reset_index(drop=True, inplace=True)
        return self.dt
    
    def remove_column(self, input_list):
        self.dt.drop(input_list, axis=1, inplace=True) #받은 값이라
        return self.dt

dt = Change_dt("./csv/Sales Records.csv")

# %%
dt.csv_read()
# Out:
#                             Region      Country        Item Type  \
# 0     Middle East and North Africa  Afghanistan           Cereal
# 1     Middle East and North Africa  Afghanistan        Household
# 2     Middle East and North Africa  Afghanistan           Cereal
# 3     Middle East and North Africa  Afghanistan             Meat
# 4     Middle East and North Africa  Afghanistan        Household
# ...                            ...          ...              ...
# 9995            Sub-Saharan Africa     Zimbabwe           Cereal
# 9996            Sub-Saharan Africa     Zimbabwe  Office Supplies
# 9997            Sub-Saharan Africa     Zimbabwe           Fruits
# 9998            Sub-Saharan Africa     Zimbabwe          Clothes
# 9999            Sub-Saharan Africa     Zimbabwe           Fruits
#
#      Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0          Offline              H   7/24/2013  933963477   8/23/2013
# ...

# %%
dt.remove_column("Sales Channel")
# Out:
#                             Region      Country        Item Type  \
# 0     Middle East and North Africa  Afghanistan           Cereal
# 1     Middle East and North Africa  Afghanistan        Household
# 2     Middle East and North Africa  Afghanistan           Cereal
# 3     Middle East and North Africa  Afghanistan             Meat
# 4     Middle East and North Africa  Afghanistan        Household
# ...                            ...          ...              ...
# 9995            Sub-Saharan Africa     Zimbabwe           Cereal
# 9996            Sub-Saharan Africa     Zimbabwe  Office Supplies
# 9997            Sub-Saharan Africa     Zimbabwe           Fruits
# 9998            Sub-Saharan Africa     Zimbabwe          Clothes
# 9999            Sub-Saharan Africa     Zimbabwe           Fruits
#
#      Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0                 H   7/24/2013  933963477   8/23/2013        9402
# ...

# %%
from module import mod2
mod2.sub(5,3)
# Out:
# 2
# 2

# %%
from mod3 import add, sub

# %%
add(5,3)
# Out:
# 8

# %%
sub(5,3)
# Out:
# 2

# %%
# 클래스 모듈로 만들어서 모듈로 import

import mod4.Change_dt_2("./csv/Sales Records.csv")
# Out:
#   Input In [21]
#     import mod4.Change_dt_2("./csv/Sales Records.csv")
#                            ^
# SyntaxError: invalid syntax

# %%
dt.csv_read()

# %%
dt.remove_2("Item Type")

# %%
from mod4 import Change_dt_2 as ct

dt_2 = ct("./csv/Sales Records.csv")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\KimTaeyong\Desktop\My Python\jupyter\220308.ipynb Cell 12' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KimTaeyong/Desktop/My%20Python/jupyter/220308.ipynb#ch0000013?line=0'>1</a> from mod4 import Change_dt_2 as ct
#       <a href='vscode-notebook-cell:/c%3A/Users/KimTaeyong/Desktop/My%20Python/jupyter/220308.ipynb#ch0000013?line=2'>3</a> dt_2 = ct("./csv/Sales Records.csv")
#
# ImportError: cannot import name 'Change_dt_2' from 'mod4' (c:\Users\KimTaeyong\Desktop\My Python\jupyter\mod4.py)

# %%
dt_2.csv_read()

# %%
import numpy as np

# %%
n_a = np.random.random((10,2))
n_a
# Out:
# array([[0.01482953, 0.99352224],
#        [0.35764896, 0.0823205 ],
#        [0.93082066, 0.28620039],
#        [0.09826903, 0.61682326],
#        [0.2623159 , 0.78062849],
#        [0.11483016, 0.67191825],
#        [0.54209108, 0.38897728],
#        [0.30938468, 0.42500286],
#        [0.7699329 , 0.74758972],
#        [0.39611211, 0.83392014]])

# %%
import pandas as pd
dt = pd.DataFrame(n_a)
dt

# for i in range(len(n_a)):
#     if n_a[i][1] > 0.5:
#         n_a[i][1] = 1
#     else:
#         n_a[i][1] = 0


# n_a
# Out:
#           0    1
# 0  0.014830  1.0
# 1  0.357649  0.0
# 2  0.930821  0.0
# 3  0.098269  1.0
# 4  0.262316  1.0
# 5  0.114830  1.0
# 6  0.542091  0.0
# 7  0.309385  0.0
# 8  0.769933  1.0
# 9  0.396112  1.0

# %%
dt[1].round(0)
# Out:
# 0    1.0
# 1    0.0
# 2    0.0
# 3    1.0
# 4    1.0
# 5    1.0
# 6    0.0
# 7    0.0
# 8    1.0
# 9    1.0
# Name: 1, dtype: float64

# %%
dt[1].apply(lambda x : 1 if (x>0.5) else 0)
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# 5    1
# 6    0
# 7    0
# 8    1
# 9    1
# Name: 1, dtype: int64

# %%
def _round(x):
    if x > 0.5:
        return 1
    else:
        return 0
dt[1].apply(_round)
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# 5    1
# 6    0
# 7    0
# 8    1
# 9    1
# Name: 1, dtype: int64

# %%
# class 다중상속
class Class_1():
    def a(self):
        print("Class_1")

class Class_2():
    def b(self):
        print("Class_2")

class Class_3(Class_2, Class_1):
    def c(self):
        print("Class_3")

x = Class_3()

# %%
x.a()
# Out:
# Class_1
