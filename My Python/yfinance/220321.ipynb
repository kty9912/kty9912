# %%
import yfinance as yf
import pandas as pd

# %%
yf.download('AAPL', start= '2019-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-31   39.632500   39.840000   39.119999   39.435001   38.233902
# 2019-01-02   38.722500   39.712502   38.557499   39.480000   38.277523
# 2019-01-03   35.994999   36.430000   35.500000   35.547501   34.464802
# 2019-01-04   36.132500   37.137501   35.950001   37.064999   35.936077
# 2019-01-07   37.174999   37.207500   36.474998   36.982498   35.856094
# ...                ...         ...         ...         ...         ...
# 2022-03-14  151.449997  154.119995  150.100006  150.619995  150.619995
# 2022-03-15  150.899994  155.570007  150.380005  155.089996  155.089996
# 2022-03-16  157.050003  160.000000  154.460007  159.589996  159.589996
# 2022-03-17  158.610001  161.000000  157.630005  160.619995  160.619995
# 2022-03-18  160.509995  164.479996  159.759995  163.979996  163.979996
#
#                Volume
# Date
# ...

# %%
data = yf.download(["AAPL", "TSLA", "AMZN", "CPNG"], start="2019-01-01")
data
# Out:
# [*********************100%***********************]  4 of 4 completed
#              Adj Close                                           Close  \
#                   AAPL         AMZN       CPNG        TSLA        AAPL
# Date
# 2018-12-31   38.233891  1501.969971        NaN   66.559998   39.435001
# 2019-01-02   38.277519  1539.130005        NaN   62.023998   39.480000
# 2019-01-03   34.464798  1500.280029        NaN   60.071999   35.547501
# 2019-01-04   35.936069  1575.390015        NaN   63.537998   37.064999
# 2019-01-07   35.856094  1629.510010        NaN   66.991997   36.982498
# ...                ...          ...        ...         ...         ...
# 2022-03-14  150.619995  2837.060059  16.120001  766.369995  150.619995
# 2022-03-15  155.089996  2947.330078  15.450000  801.890015  155.089996
# 2022-03-16  159.589996  3062.080078  18.090000  840.229980  159.589996
# 2022-03-17  160.619995  3144.780029  19.200001  871.599976  160.619995
# ...

# %%
data['Close']['AAPL']
# Out:
# Date
# 2018-12-31     39.435001
# 2019-01-02     39.480000
# 2019-01-03     35.547501
# 2019-01-04     37.064999
# 2019-01-07     36.982498
#                  ...
# 2022-03-14    150.619995
# 2022-03-15    155.089996
# 2022-03-16    159.589996
# 2022-03-17    160.619995
# 2022-03-18    163.979996
# Name: AAPL, Length: 811, dtype: float64

# %%
aapl = yf.Ticker("AAPL")  #지정

# %%
aapl.dividends #배당
# Out:
# Date
# 1987-05-11    0.000536
# 1987-08-10    0.000536
# 1987-11-17    0.000714
# 1988-02-12    0.000714
# 1988-05-16    0.000714
#                 ...
# 2021-02-05    0.205000
# 2021-05-07    0.220000
# 2021-08-06    0.220000
# 2021-11-05    0.220000
# 2022-02-04    0.220000
# Name: Dividends, Length: 74, dtype: float64

# %%
aapl.splits #주식분할
# Out:
# Date
# 1987-06-16    2.0
# 2000-06-21    2.0
# 2005-02-28    2.0
# 2014-06-09    7.0
# 2020-08-31    4.0
# Name: Stock Splits, dtype: float64

# %%
aapl.recommendations  # 애널리스트 정보
# Out:
#                                     Firm      To Grade From Grade Action
# Date
# 2012-02-09 08:17:00    Canaccord Genuity           Buy              main
# 2012-03-08 07:33:00       FBN Securities    Outperform              main
# 2012-03-13 06:08:00            Jefferies           Buy              main
# 2012-03-14 06:13:00       Morgan Stanley    Overweight              main
# 2012-03-14 08:21:00    Canaccord Genuity           Buy              main
# ...                                  ...           ...        ...    ...
# 2022-01-28 14:19:01  New Street Research       Neutral       Sell     up
# 2022-01-28 15:10:56          Oppenheimer    Outperform              main
# 2022-01-31 15:44:19        Credit Suisse       Neutral              main
# 2022-02-15 15:31:58    Tigress Financial    Strong Buy              main
# 2022-03-11 11:57:08             Barclays  Equal-Weight              main
#
# [831 rows x 4 columns]

# %%
aapl.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 100000,
# ...

# %%
aapl.history(period='max')
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 1980-12-12    0.100323    0.100759    0.100323    0.100323  469033600
# 1980-12-15    0.095525    0.095525    0.095089    0.095089  175884800
# 1980-12-16    0.088546    0.088546    0.088110    0.088110  105728000
# 1980-12-17    0.090291    0.090727    0.090291    0.090291   86441600
# 1980-12-18    0.092908    0.093345    0.092908    0.092908   73449600
# ...                ...         ...         ...         ...        ...
# 2022-03-14  151.449997  154.119995  150.100006  150.619995  108732100
# 2022-03-15  150.899994  155.570007  150.380005  155.089996   92964300
# 2022-03-16  157.050003  160.000000  154.460007  159.589996  102300200
# 2022-03-17  158.610001  161.000000  157.630005  160.619995   75615400
# 2022-03-18  160.509995  164.479996  159.759995  163.979996  123351200
#
#             Dividends  Stock Splits
# Date
# 1980-12-12        0.0           0.0
# 1980-12-15        0.0           0.0
# ...

# %%
cpng = yf.Ticker("CPNG")
cpng.info
# Out:
# {'zip': '05510',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 68000,
#  'longBusinessSummary': 'Coupang, Inc. owns and operates in e-commerce business through its mobile applications and Internet websites primarily in South Korea. It operates through two segments, Product Commerce and Growth Initiatives. The company sells various products and services in the categories of home goods and dÃ©cor products, apparel, beauty products, fresh food and groceries, sporting goods, electronics, and everyday consumables, as well as travel, and restaurant order and delivery services. It also performs operations and support services in China, Singapore, Japan, Taiwan, and the United States. Coupang, Inc. was incorporated in 2010 and is headquartered in Seoul, South Korea.',
#  'city': 'Seoul',
#  'phone': '82 2 6150 5422',
#  'country': 'South Korea',
#  'companyOfficers': [],
#  'website': 'https://www.coupang.com',
#  'maxAge': 1,
#  'address1': 'Tower 730,570',
# ...

# %%
cpng.history(period='max')
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2021-03-11  63.500000  69.000000  49.250000  49.250000  91584100          0
# 2021-03-12  52.540001  52.759998  46.250000  48.470001  30521000          0
# 2021-03-15  50.130001  51.849998  49.020000  50.450001  17387800          0
# 2021-03-16  50.590000  50.770000  46.700001  47.130001  14552400          0
# 2021-03-17  46.000000  46.900002  43.189999  43.290001  15251100          0
# ...               ...        ...        ...        ...       ...        ...
# 2022-03-14  17.040001  17.488001  15.920000  16.120001  17621600          0
# 2022-03-15  16.070000  16.959999  15.275000  15.450000  30197600          0
# 2022-03-16  16.000000  18.120001  15.820000  18.090000  40631500          0
# 2022-03-17  17.680000  19.245001  17.400000  19.200001  19894800          0
# 2022-03-18  18.629999  19.920000  18.490000  19.240000  16530900          0
#
#             Stock Splits
# Date
# ...

# %%
cpng.history(start = '2022-01-01')
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2021-12-31  29.660000  30.225000  29.340000  29.379999   3890800          0
# 2022-01-03  29.650000  29.650000  28.410000  28.719999   4278100          0
# 2022-01-04  28.570000  28.700001  26.379999  26.410000  11873200          0
# 2022-01-05  26.700001  26.816999  25.389999  25.610001   9257300          0
# 2022-01-06  25.510000  25.889999  24.510000  25.660000   7126900          0
# 2022-01-07  25.629999  26.295000  25.549999  25.969999   6481700          0
# 2022-01-10  25.559999  25.629999  22.879999  24.120001  16072900          0
# 2022-01-11  23.879999  25.094999  23.879999  25.049999   7363900          0
# 2022-01-12  25.135000  25.480000  23.379999  23.440001  10391600          0
# 2022-01-13  23.490000  23.559999  22.275000  22.420000  10094100          0
# 2022-01-14  22.139999  22.330000  20.709999  21.209999  14656700          0
# ...

# %%
import pyupbit as upbit

# %%
upbit.get_tickers(fiat='KRW')
# Out:
# ['KRW-BTC',
#  'KRW-ETH',
#  'KRW-NEO',
#  'KRW-MTL',
#  'KRW-LTC',
#  'KRW-XRP',
#  'KRW-ETC',
#  'KRW-OMG',
#  'KRW-SNT',
#  'KRW-WAVES',
#  'KRW-XEM',
#  'KRW-QTUM',
#  'KRW-LSK',
#  'KRW-STEEM',
#  'KRW-XLM',
#  'KRW-ARDR',
#  'KRW-ARK',
#  'KRW-STORJ',
#  'KRW-GRS',
#  'KRW-REP',
#  'KRW-ADA',
#  'KRW-SBD',
#  'KRW-POWR',
#  'KRW-BTG',
#  'KRW-ICX',
#  'KRW-EOS',
#  'KRW-TRX',
#  'KRW-SC',
#  'KRW-ONT',
#  'KRW-ZIL',
#  'KRW-POLY',
#  'KRW-ZRX',
#  'KRW-LOOM',
#  'KRW-BCH',
#  'KRW-BAT',
#  'KRW-IOST',
#  'KRW-RFR',
#  'KRW-CVC',
#  'KRW-IQ',
#  'KRW-IOTA',
#  'KRW-MFT',
#  'KRW-ONG',
#  'KRW-GAS',
#  'KRW-UPP',
#  'KRW-ELF',
#  'KRW-KNC',
#  'KRW-BSV',
#  'KRW-THETA',
#  'KRW-QKC',
#  'KRW-BTT',
#  'KRW-MOC',
#  'KRW-ENJ',
#  'KRW-TFUEL',
#  'KRW-MANA',
#  'KRW-ANKR',
#  'KRW-AERGO',
#  'KRW-ATOM',
#  'KRW-TT',
#  'KRW-CRE',
#  'KRW-MBL',
#  'KRW-WAXP',
#  'KRW-HBAR',
#  'KRW-MED',
#  'KRW-MLK',
#  'KRW-STPT',
#  'KRW-ORBS',
#  'KRW-VET',
#  'KRW-CHZ',
#  'KRW-STMX',
# ...

# %%
upbit.get_current_price(["KRW-BTC","KRW-ETH"])
# Out:
# {'KRW-BTC': 50085000.0, 'KRW-ETH': 3508000.0}

# %%
ticker = 'KRW-BTC'
interval = "week"
to = "2022-01-01 00:00"
count = 100
upbit.get_ohlcv(ticker=ticker, interval=interval)
# Out:
#                            open        high         low       close  \
# 2018-05-28 09:00:00   8182000.0   8443000.0   7813000.0   8419000.0
# 2018-06-04 09:00:00   8419000.0   8490000.0   7425000.0   7576000.0
# 2018-06-11 09:00:00   7576000.0   7685000.0   6951000.0   7218000.0
# 2018-06-18 09:00:00   7231000.0   7649000.0   6622000.0   6992000.0
# 2018-06-25 09:00:00   6985000.0   7290000.0   6590000.0   7109000.0
# ...                         ...         ...         ...         ...
# 2022-02-21 09:00:00  47133000.0  49010000.0  42580000.0  46358000.0
# 2022-02-28 09:00:00  46363000.0  54829000.0  46086000.0  47745000.0
# 2022-03-07 09:00:00  47782000.0  52300000.0  46525000.0  47510000.0
# 2022-03-14 09:00:00  47500000.0  51350000.0  47186000.0  50462000.0
# 2022-03-21 09:00:00  50471000.0  50756000.0  49832000.0  50085000.0
#
#                            volume         value
# 2018-05-28 09:00:00  35402.938083  2.913398e+11
# 2018-06-04 09:00:00  25886.893761  2.115380e+11
# ...

# %% [markdown]
# #### 3시30분 프리 데이터 튜닝
# 1. 주식, 코인 데이터를 가지고 데이터 갯수 1000개 선택
# 2. 데이터를 csv로 변환
# 3. csv를 DB 삽입
# 4. mysql query데이터를 받아오는데 (Module생성, Class로 구현)
# 5. 주식의 기준 -> 시가, 종가, 고가, 저가 소수점 2번째 자리까지 유지 반올림
# 6. 코인의 기준 -> 볼륨 소수점 2번째 자리까지 유지 반올림
# 7. 주식기준 Nan 값 존재 시작되는 지점의 시가로 변환
# 8. 컬럼을 하나 추가 종가-시가의 값을 삽입
# 9. 컬럼을 하나 추가 (등락폭/시가 * 100) 퍼센트를 삽입
# 10. 데이터의 시각화 -> 시가/ 종가/ 등락폭 / 볼륨 그래프 4개를 한 plot 표시

# %%
import yfinance as yf
import pandas as pd

# %%
has = yf.download("012450.KS", start='2018-01-01')
has
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close     Adj Close  Volume
# Date
# 2018-01-02  36000.0  36550.0  35600.0  36500.0  35196.742188  355321
# 2018-01-03  36600.0  36700.0  36100.0  36500.0  35196.742188  289206
# 2018-01-04  36600.0  36600.0  36100.0  36450.0  35148.527344  235820
# 2018-01-05  36700.0  37200.0  35600.0  35850.0  34569.953125  341107
# 2018-01-08  35850.0  36050.0  34900.0  35050.0  33798.515625  357572
# ...             ...      ...      ...      ...           ...     ...
# 2022-03-15  54700.0  54700.0  54700.0  54700.0  54700.000000       0
# 2022-03-16  54700.0  54700.0  54700.0  54700.0  54700.000000       0
# 2022-03-17  54700.0  54700.0  54700.0  54700.0  54700.000000       0
# 2022-03-18  50600.0  51500.0  49800.0  51400.0  51400.000000  706241
# 2022-03-21  51700.0  52800.0  51300.0  51700.0  51700.000000  484741
#
# [1036 rows x 6 columns]

# %%
has.to_csv("has.csv")
pd.read_csv("has.csv")
# Out:
#             Date     Open     High      Low    Close     Adj Close  Volume
# 0     2018-01-02  36000.0  36550.0  35600.0  36500.0  35196.742188  355321
# 1     2018-01-03  36600.0  36700.0  36100.0  36500.0  35196.742188  289206
# 2     2018-01-04  36600.0  36600.0  36100.0  36450.0  35148.527344  235820
# 3     2018-01-05  36700.0  37200.0  35600.0  35850.0  34569.953125  341107
# 4     2018-01-08  35850.0  36050.0  34900.0  35050.0  33798.515625  357572
# ...          ...      ...      ...      ...      ...           ...     ...
# 1031  2022-03-15  54700.0  54700.0  54700.0  54700.0  54700.000000       0
# 1032  2022-03-16  54700.0  54700.0  54700.0  54700.0  54700.000000       0
# 1033  2022-03-17  54700.0  54700.0  54700.0  54700.0  54700.000000       0
# 1034  2022-03-18  50600.0  51500.0  49800.0  51400.0  51400.000000  706241
# 1035  2022-03-21  51700.0  52800.0  51300.0  51700.0  51700.000000  484741
#
# [1036 rows x 7 columns]

# %%
# _sql = """ 
#       CREATE 
# """

# %%
has.index
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-08', '2018-01-09', '2018-01-10', '2018-01-11',
#                '2018-01-12', '2018-01-15',
#                ...
#                '2022-03-07', '2022-03-08', '2022-03-10', '2022-03-11',
#                '2022-03-14', '2022-03-15', '2022-03-16', '2022-03-17',
#                '2022-03-18', '2022-03-21'],
#               dtype='datetime64[ns]', name='Date', length=1036, freq=None)

# %%
list(has.Open)
# Out:
# [36000.0,
#  36600.0,
#  36600.0,
#  36700.0,
#  35850.0,
#  35100.0,
#  35450.0,
#  35000.0,
#  34650.0,
#  33700.0,
#  33000.0,
#  33350.0,
#  33100.0,
#  33700.0,
#  33600.0,
#  33150.0,
#  33050.0,
#  33350.0,
#  33200.0,
#  34500.0,
#  34300.0,
#  34000.0,
#  33750.0,
#  33600.0,
#  32500.0,
#  30200.0,
#  30700.0,
#  29850.0,
#  28500.0,
#  28150.0,
#  27500.0,
#  27250.0,
#  27950.0,
#  28800.0,
#  28650.0,
#  28400.0,
#  28400.0,
#  28750.0,
#  29800.0,
#  28700.0,
#  29000.0,
#  27850.0,
#  27750.0,
#  27700.0,
#  27950.0,
#  28450.0,
#  28550.0,
#  29300.0,
#  29400.0,
#  29000.0,
#  29500.0,
#  29250.0,
#  28750.0,
#  28800.0,
#  30350.0,
#  29400.0,
#  29000.0,
#  28750.0,
#  28600.0,
#  28600.0,
#  28950.0,
#  29450.0,
#  28300.0,
#  28650.0,
#  27700.0,
#  27600.0,
#  27500.0,
#  27550.0,
#  26950.0,
#  26950.0,
#  27200.0,
#  27150.0,
#  26500.0,
#  26450.0,
#  26550.0,
#  25850.0,
#  26000.0,
#  25150.0,
#  25250.0,
#  25100.0,
#  26200.0,
#  25750.0,
#  23850.0,
# ...

# %%
has
# Out:
#                Open     High      Low    Close     Adj Close  Volume
# Date
# 2018-01-02  36000.0  36550.0  35600.0  36500.0  35196.742188  355321
# 2018-01-03  36600.0  36700.0  36100.0  36500.0  35196.742188  289206
# 2018-01-04  36600.0  36600.0  36100.0  36450.0  35148.527344  235820
# 2018-01-05  36700.0  37200.0  35600.0  35850.0  34569.953125  341107
# 2018-01-08  35850.0  36050.0  34900.0  35050.0  33798.515625  357572
# ...             ...      ...      ...      ...           ...     ...
# 2022-03-15  54700.0  54700.0  54700.0  54700.0  54700.000000       0
# 2022-03-16  54700.0  54700.0  54700.0  54700.0  54700.000000       0
# 2022-03-17  54700.0  54700.0  54700.0  54700.0  54700.000000       0
# 2022-03-18  50600.0  51500.0  49800.0  51400.0  51400.000000  706241
# 2022-03-21  51700.0  52800.0  51300.0  51700.0  51700.000000  484741
#
# [1036 rows x 6 columns]

# %%
# _sql2 = """ 
#         INSERT INTO has values( 
#             %s, %s, %s, %s, %s
#         )
#     """
# for i in range(len(has)):
#     _db.execute(_sql2, [has.index[i], has.Open[i], 
#     has.High[i], 
#     has.Low[i], 
#     has.Close[i]])
# _db.commit()

# %%
_sql = """ 
         SELECT * FROM has LIMIT 1000
         """
has = _db.executeAll(_sql)

# %%
_df = pd.DataFrame(has)

# %%
_df["등락폭"] = _df["Close"]-_df["Open"]
_df
# Out:
#                Open     High      Low    Close     Adj Close  Volume    등락폭
# Date
# 2018-01-02  36000.0  36550.0  35600.0  36500.0  35196.742188  355321  500.0
# 2018-01-03  36600.0  36700.0  36100.0  36500.0  35196.742188  289206 -100.0
# 2018-01-04  36600.0  36600.0  36100.0  36450.0  35148.527344  235820 -150.0
# 2018-01-05  36700.0  37200.0  35600.0  35850.0  34569.953125  341107 -850.0
# 2018-01-08  35850.0  36050.0  34900.0  35050.0  33798.515625  357572 -800.0
# ...             ...      ...      ...      ...           ...     ...    ...
# 2022-03-15  54700.0  54700.0  54700.0  54700.0  54700.000000       0    0.0
# 2022-03-16  54700.0  54700.0  54700.0  54700.0  54700.000000       0    0.0
# 2022-03-17  54700.0  54700.0  54700.0  54700.0  54700.000000       0    0.0
# 2022-03-18  50600.0  51500.0  49800.0  51400.0  51400.000000  706241  800.0
# 2022-03-21  51700.0  52800.0  51300.0  51700.0  51700.000000  484741    0.0
#
# [1036 rows x 7 columns]

# %%
_df["등락률"] = _df["등락폭"] / _df["Open"] * 100
_df
# Out:
#                Open     High      Low    Close     Adj Close  Volume    등락폭  \
# Date
# 2018-01-02  36000.0  36550.0  35600.0  36500.0  35196.742188  355321  500.0
# 2018-01-03  36600.0  36700.0  36100.0  36500.0  35196.742188  289206 -100.0
# 2018-01-04  36600.0  36600.0  36100.0  36450.0  35148.527344  235820 -150.0
# 2018-01-05  36700.0  37200.0  35600.0  35850.0  34569.953125  341107 -850.0
# 2018-01-08  35850.0  36050.0  34900.0  35050.0  33798.515625  357572 -800.0
# ...             ...      ...      ...      ...           ...     ...    ...
# 2022-03-15  54700.0  54700.0  54700.0  54700.0  54700.000000       0    0.0
# 2022-03-16  54700.0  54700.0  54700.0  54700.0  54700.000000       0    0.0
# 2022-03-17  54700.0  54700.0  54700.0  54700.0  54700.000000       0    0.0
# 2022-03-18  50600.0  51500.0  49800.0  51400.0  51400.000000  706241  800.0
# 2022-03-21  51700.0  52800.0  51300.0  51700.0  51700.000000  484741    0.0
#
#                  등락률
# Date
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(2,2,1) 
plt.plot(_df["Open"])
plt.subplot(2,2,2)
plt.plot(_df["Close"])
plt.subplot(2,2,3)
plt.plot(_df["등락폭"])
plt.subplot(2,2,4)
plt.plot(_df["등락률"])
plt.show()
